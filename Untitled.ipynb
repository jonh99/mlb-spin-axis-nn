# %%
import pybaseball
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
from pybaseball import statcast

# %%
data = statcast(start_dt='2017-06-24', end_dt='2017-06-27')
# Out:
# This is a large query, it may take a moment to complete
# 100%|██████████| 4/4 [00:04<00:00,  1.20s/it]

# %%
print(len(data.index))
# Out:
# 15949

# %%
data.head(200)
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 3323         CU 2017-06-27           79.7          -1.34           5.41
# 3416         FF 2017-06-27           98.1          -1.35           5.42
# 3545         FF 2017-06-27           98.3          -1.29           5.45
# 3640         FC 2017-06-27           90.9          -1.46           5.25
# 3815         SI 2017-06-27           99.1          -1.37           5.34
# ...         ...        ...            ...            ...            ...
# 1588         SL 2017-06-27           84.0           -1.7            6.7
# 1605         FF 2017-06-27           88.9          -1.86           6.74
# 1648         SL 2017-06-27           87.4          -1.83           6.68
# 1673         SL 2017-06-27           84.3          -1.93           6.68
# 1711         FF 2017-06-27           92.9          -1.79           6.69
#
#       player_name  batter  pitcher     events    description  ...  fld_score  \
# 3323   Bush, Matt  608070   456713  field_out  hit_into_play  ...          2
# 3416   Bush, Matt  429665   456713  field_out  hit_into_play  ...          2
# 3545   Bush, Matt  429665   456713        NaN           ball  ...          2
# 3640   Bush, Matt  429665   456713        NaN  called_strike  ...          2
# 3815   Bush, Matt  488726   456713     single  hit_into_play  ...          2
# ...           ...     ...      ...        ...            ...  ...        ...
# 1588  Ross, Tyson  543401   475115  field_out  hit_into_play  ...          0
# 1605  Ross, Tyson  543401   475115        NaN           foul  ...          0
# 1648  Ross, Tyson  543401   475115        NaN           ball  ...          0
# 1673  Ross, Tyson  543401   475115        NaN  called_strike  ...          0
# 1711  Ross, Tyson  543228   475115       walk           ball  ...          0
#
#       post_away_score  post_home_score  post_bat_score  post_fld_score  \
# 3323                2                1               1               2
# 3416                2                1               1               2
# 3545                2                1               1               2
# 3640                2                1               1               2
# 3815                2                1               1               2
# ...               ...              ...             ...             ...
# 1588                0                1               1               0
# 1605                0                1               1               0
# 1648                0                1               1               0
# 1673                0                1               1               0
# 1711                0                1               1               0
#
#      if_fielding_alignment of_fielding_alignment spin_axis delta_home_win_exp  \
# 3323              Standard             Strategic        51             -0.096
# 3416              Standard             Strategic       204              -0.11
# 3545              Standard             Strategic       202                0.0
# 3640              Standard             Strategic       142                0.0
# 3815              Standard             Strategic       230              0.098
# ...                    ...                   ...       ...                ...
# 1588              Standard              Standard        65              -0.03
# 1605              Standard              Standard       183                0.0
# 1648              Standard              Standard       153                0.0
# 1673              Standard              Standard       160                0.0
# 1711              Standard              Standard       198              0.032
#
#      delta_run_exp
# 3323        -0.227
# 3416        -0.292
# 3545         0.023
# 3640        -0.046
# 3815         0.263
# ...            ...
# 1588        -0.271
# 1605        -0.086
# 1648         0.042
# 1673        -0.061
# 1711         0.233
#
# [200 rows x 92 columns]

# %%
# Creating a dataframe with 75%
# values of original dataframe
train_df = data.sample(frac = 0.75)
 
# Creating dataframe with
# rest of the 25% values
test_df = data.drop(train_df.index)



print("\n75% of the given DataFrame:")
print(train_df)
 
print("\nrest 25% of the given DataFrame:")
print(test_df)
# Out:
# 75% of the given DataFrame:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 1729         SL 2017-06-27           84.4          -2.05           5.87
# 4431         FF 2017-06-27           94.3          -2.15           5.96
# 883          FF 2017-06-25           89.8           2.23           6.18
# 2219         FF 2017-06-24           95.3          -1.34           5.82
# 3836         SL 2017-06-24           82.0          -2.46            5.4
# ...         ...        ...            ...            ...            ...
# 4249         SI 2017-06-25           92.7          -1.69           5.66
# 3370         SI 2017-06-24           88.5           -3.3           3.62
# 3591         FF 2017-06-25           95.7          -1.98           6.04
# 1747         CH 2017-06-26           84.3           1.72           6.17
# 1499         FF 2017-06-26           93.9          -2.64           5.97
#
#              player_name  batter  pitcher     events      description  ...  \
# 1729        Maeda, Kenta  445926   628317        NaN             ball  ...
# 4431        Tepera, Ryan  430945   572193        NaN  swinging_strike  ...
# 883       Holland, Derek  501981   502706       walk             ball  ...
# 2219    Infante, Gregory  475174   500872     single    hit_into_play  ...
# 3836          Zych, Tony  543807   543964        NaN             ball  ...
# ...                  ...     ...      ...        ...              ...  ...
# 4249    Volquez, Edinson  592178   450172        NaN    called_strike  ...
# 3370       Cishek, Steve  621043   518553        NaN     blocked_ball  ...
# 3591         Green, Chad  518960   643338        NaN             foul  ...
# 1747        Avilán, Luis  488862   501593        NaN  swinging_strike  ...
# 1499  Strickland, Hunter  518934   519326  field_out    hit_into_play  ...
#
#       fld_score  post_away_score  post_home_score  post_bat_score  \
# 1729          0                0                0               0
# 4431          0                3                0               3
# 883           1                0                1               0
# 2219          2                8                2               8
# 3836          1                2                1               2
# ...         ...              ...              ...             ...
# 4249          0                0                0               0
# 3370          1                2                1               2
# 3591          4                7                4               7
# 1747          0                3                0               3
# 1499          5                2                5               2
#
#       post_fld_score if_fielding_alignment of_fielding_alignment spin_axis  \
# 1729               0             Strategic              Standard       159
# 4431               0              Standard              Standard       212
# 883                1              Standard              Standard       143
# 2219               2         Infield shift              Standard       202
# 3836               1              Standard              Standard       102
# ...              ...                   ...                   ...       ...
# 4249               0              Standard              Standard       230
# 3370               1              Standard              Standard       255
# 3591               4              Standard              Standard       189
# 1747               0              Standard              Standard       135
# 1499               5              Standard              Standard       212
#
#      delta_home_win_exp delta_run_exp
# 1729                0.0         0.014
# 4431                0.0        -0.037
# 883               -0.07         0.444
# 2219             -0.002         0.277
# 3836                0.0         0.026
# ...                 ...           ...
# 4249                0.0        -0.032
# 3370                0.0         0.126
# 3591                0.0           0.0
# 1747                0.0        -0.032
# 1499              0.081        -0.899
#
# [11962 rows x 92 columns]
#
# rest 25% of the given DataFrame:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 3129         CU 2017-06-27           78.7          -1.82            5.8
# 4382         FF 2017-06-27           96.1          -1.77           5.77
# 3980         SL 2017-06-27           81.0          -1.93           5.52
# 4508         FF 2017-06-27           93.8           -2.0           5.26
# 4113         FF 2017-06-27           95.2          -1.89           5.48
# ...         ...        ...            ...            ...            ...
# 703          FF 2017-06-24           92.9          -0.96           5.98
# 2910         CU 2017-06-24           73.5           -0.9           6.01
# 2609         SL 2017-06-24           85.6          -1.56           6.32
# 3088         CH 2017-06-24           82.6          -1.07           5.88
# 4113         FF 2017-06-24           91.9          -1.47           6.59
#
#           player_name  batter  pitcher  events      description  ...  \
# 3129    Leclerc, José  502082   600917     NaN             ball  ...
# 4382    Leclerc, José  429665   600917     NaN    called_strike  ...
# 3980  Clevinger, Mike  592261   605182     NaN             foul  ...
# 4508  Clevinger, Mike  592261   605182     NaN    called_strike  ...
# 4113   Hudson, Daniel  572816   543339     NaN  swinging_strike  ...
# ...               ...     ...      ...     ...              ...  ...
# 703      Bundy, Dylan  572816   605164     NaN    called_strike  ...
# 2910     Bundy, Dylan  519306   605164     NaN             ball  ...
# 2609      Faria, Jake  444432   607188     NaN             ball  ...
# 3088     Bundy, Dylan  489149   605164  single    hit_into_play  ...
# 4113      Faria, Jake  452234   607188     NaN    called_strike  ...
#
#       fld_score  post_away_score  post_home_score  post_bat_score  \
# 3129          1                1                1               1
# 4382          1                1                1               1
# 3980          0                0                0               0
# 4508          0                0                0               0
# 4113          0                2                0               2
# ...         ...              ...              ...             ...
# 703           3                3                3               3
# 2910          2                2                0               0
# 2609          0                0                0               0
# 3088          0                0                0               0
# 4113          0                0                0               0
#
#       post_fld_score if_fielding_alignment of_fielding_alignment spin_axis  \
# 3129               1              Standard              Standard        72
# 4382               1         Infield shift              Standard       195
# 3980               0              Standard              Standard       118
# 4508               0              Standard              Standard       211
# 4113               0         Infield shift              Standard       214
# ...              ...                   ...                   ...       ...
# 703                3         Infield shift              Standard       207
# 2910               2              Standard              Standard        20
# 2609               0         Infield shift              Standard       124
# 3088               0         Infield shift              Standard       240
# 4113               0         Infield shift              Standard       192
#
#      delta_home_win_exp delta_run_exp
# 3129                0.0         0.014
# 4382                0.0        -0.046
# 3980                0.0           0.0
# 4508                0.0        -0.037
# 4113                0.0        -0.069
# ...                 ...           ...
# 703                 0.0        -0.018
# 2910                0.0         0.027
# 2609                0.0         0.065
# 3088             -0.022         0.262
# 4113                0.0        -0.046
#
# [164 rows x 92 columns]

# %%
cut_train_df = train_df[['release_speed', 'release_pos_x', 'release_pos_z', 'spin_axis']].dropna()

# %%
cut_test_df = test_df[['release_speed', 'release_pos_x','release_pos_z','spin_axis']].dropna()

# %%
cut_test_df.head(20)
# Out:
#       release_speed  release_pos_x  release_pos_z  spin_axis
# 3129           78.7          -1.82            5.8         72
# 4382           96.1          -1.77           5.77        195
# 3980           81.0          -1.93           5.52        118
# 4508           93.8           -2.0           5.26        211
# 4113           95.2          -1.89           5.48        214
# 999            82.6          -2.14           5.74         58
# 2820           78.1          -1.96           6.28         48
# 3574           80.2          -1.97           5.97         22
# 4385           94.0          -2.42           5.64        211
# 3653           87.2           2.36           6.04        163
# 3341           99.4          -0.51           6.41        203
# 4477           90.8           0.45           6.63        131
# 2609           94.8           -1.8           5.47        257
# 3288           87.6           -1.7           5.46        275
# 3309           86.9          -2.47           5.43        111
# 703            83.9          -2.44           4.75        268
# 3006           96.9            2.6           6.23        145
# 3342           94.0          -1.95           6.46        248
# 4128           82.9          -2.25           6.23         32
# 3321           83.7          -1.32           6.18         60

# %%
# Calculate the Z-scores of each column in the training set:
cut_train_df_mean = cut_train_df.mean()
cut_train_df_std = cut_train_df.std()
cut_train_df_norm = (cut_train_df - cut_train_df_mean)/cut_train_df_std

# %%
# Calculate the Z-scores of each column in the test set.
cut_test_df_mean = cut_test_df.mean()
cut_test_df_std = cut_test_df.std()
cut_test_df_norm = (cut_test_df - cut_test_df_mean)/cut_test_df_std

cut_test_df_norm.head()
# Out:
#       release_speed  release_pos_x  release_pos_z  spin_axis
# 3129      -1.579921      -0.470378       -0.07567  -1.394818
# 4382       1.124453      -0.446659      -0.135525   0.320076
# 3980      -1.222446      -0.522558      -0.634317  -0.753476
# 4508       0.766978      -0.555764       -1.15306   0.543152
# 4113       0.984572      -0.503583      -0.714124   0.584979

# %%
#tensorflow data representation

# %%
# Create an empty list that will eventually hold all created feature columns.
feature_columns = []

# %%
# We scaled all the columns, including latitude and longitude, into their
# Z scores. So, instead of picking a resolution in degrees, we're going
# to use resolution_in_Zs.  A resolution_in_Zs of 1 corresponds to 
# a full standard deviation. 
resolution_in_Zs = 0.3  # 3/10 of a standard deviation.

# %%
# Create a bucket feature column for release position x.
release_pos_x_as_a_numeric_column = tf.feature_column.numeric_column("release_pos_x")
release_pos_x_boundaries = list(np.arange(int(min(cut_train_df_norm['release_pos_x'])), 
                                     int(max(cut_train_df_norm['release_pos_x'])), 
                                     resolution_in_Zs))
release_pos_x = tf.feature_column.bucketized_column(release_pos_x_as_a_numeric_column, release_pos_x_boundaries)

# %%
# Create a bucket feature column for release position z.
release_pos_z_as_a_numeric_column = tf.feature_column.numeric_column("release_pos_z")
release_pos_z_boundaries = list(np.arange(int(min(cut_train_df_norm['release_pos_z'])), 
                                      int(max(cut_train_df_norm['release_pos_z'])), 
                                      resolution_in_Zs))
release_pos_z = tf.feature_column.bucketized_column(release_pos_z_as_a_numeric_column, 
                                                release_pos_z_boundaries)

# %%
# Create a feature cross of release pos x and y
release_x_by_release_z = tf.feature_column.crossed_column([release_pos_x, release_pos_z], hash_bucket_size=100)
crossed_feature = tf.feature_column.indicator_column(release_x_by_release_z)
feature_columns.append(crossed_feature)

# %%
# Represent release speed as a floating-point value.
release_speed = tf.feature_column.numeric_column("release_speed")
feature_columns.append(release_speed)

# %%
# Convert the list of feature columns into a layer that will later be fed into
# the model. 
my_feature_layer = tf.keras.layers.DenseFeatures(feature_columns)

# %%
#Linear Regression test

# %%
def plot_the_loss_curve(epochs, mse):
  """Plot a curve of loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Mean Squared Error")

  plt.plot(epochs, mse, label="Loss")
  plt.legend()
  plt.ylim([mse.min()*0.95, mse.max() * 1.03])
  plt.show()  

print("Defined the plot_the_loss_curve function.")
# Out:
# Defined the plot_the_loss_curve function.

# %%
#Define functions to create and train a linear regression model
def create_model(my_learning_rate, feature_layer):
  """Create and compile a simple linear regression model."""
  # Most simple tf.keras models are sequential.
  model = tf.keras.models.Sequential()

  # Add the layer containing the feature columns to the model.
  model.add(feature_layer)

  # Add one linear layer to the model to yield a simple linear regressor.
  model.add(tf.keras.layers.Dense(units=1, input_shape=(1,)))

  # Construct the layers into a model that TensorFlow can execute.
  model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.MeanSquaredError()])

  return model           


def train_model(model, dataset, epochs, batch_size, label_name):
  """Feed a dataset into the model in order to train it."""

  # Split the dataset into features and label.
  features = {name:np.array(value) for name, value in dataset.items()}
  label = np.array(features.pop(label_name))
  history = model.fit(x=features, y=label, batch_size=batch_size,
                      epochs=epochs, shuffle=True)

  # Get details that will be useful for plotting the loss curve.
  epochs = history.epoch
  hist = pd.DataFrame(history.history)
  rmse = hist["mean_squared_error"]

  return epochs, rmse   

print("Defined the create_model and train_model functions.")
# Out:
# Defined the create_model and train_model functions.

# %%
#cut_train_df_norm.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 133
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-129-e2d5e584d4f2> in <module>
#       1 #cut_train_df_norm.head(10)
# ----> 2 print(cut_test_df_norm[133])
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 133

# %%
# The following variables are the hyperparameters.
learning_rate = 0.01
epochs = 20
batch_size = 1000

# Specify the label
label_name = "spin_axis"

# Establish the model's topography.
my_model = create_model(learning_rate, my_feature_layer)

# Train the model on the normalized training set. We're passing the entire
# normalized training set, but the model will only use the features
# defined by the feature_layer.
epochs, mse = train_model(my_model, cut_train_df_norm, epochs, 
                          label_name, batch_size)
plot_the_loss_curve(epochs, mse)

# After building a model against the training set, test that model
# against the test set.
test_features = {name:np.array(value) for name, value in cut_test_df_norm.items()}
test_label = np.array(test_features.pop(label_name)) # isolate the label
print("\n Evaluate the new model against the test set:")
my_model.evaluate(x = test_features, y = test_label, batch_size=batch_size)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-125-478e4429acd1> in <module>
#      13 # normalized training set, but the model will only use the features
#      14 # defined by the feature_layer.
# ---> 15 epochs, mse = train_model(my_model, cut_train_df_norm, epochs,
#      16                           label_name, batch_size)
#      17 plot_the_loss_curve(epochs, mse)
#
# <ipython-input-121-57136ea409b3> in train_model(model, dataset, epochs, batch_size, label_name)
#      24   # Split the dataset into features and label.
#      25   features = {name:np.array(value) for name, value in dataset.items()}
# ---> 26   label = np.array(features.pop(label_name))
#      27   history = model.fit(x=features, y=label, batch_size=batch_size,
#      28                       epochs=epochs, shuffle=True)
#
# KeyError: 1000
